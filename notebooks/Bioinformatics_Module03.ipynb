# %% [markdown]
# <a href="https://colab.research.google.com/github/Hwe3836/beginning--bioinformatics/blob/main/notebooks/Bioinformatics_Module03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("Enter your name: ")
print("Hello, "+ name)
# Out:
# Enter your name: Harrison
# Hello, Harrison

# %%
a = int(input("Enter a: "))
b = int(input("Enter b: "))
print(a**2 + b**2)
# Out:
# Enter a: 2
# Enter b: 2
# 8

# %%
#Create a list with 3 elements and then print them

my_list = ["Hello", "World", "Charles Darwin"]
print(my_list[1])
# Out:
# World

# %%
#Subsitute the item at index 2 in the list
my_list[2] = "Alfred R. Wallace"
print(my_list)
# Out:
# ['Hello', 'World', 'Alfred R. Wallace']

# %%
#Append an item to the end of the list
my_list.append("Charles Darwin")
print(my_list)
# Out:
# ['Hello', 'World', 'Alfred R. Wallace', 'Charles Darwin']

# %%
# Insert an item at index 1
my_list.insert(1, "new item")
print(my_list)
# Out:
# ['Hello', 'new item', 'World', 'Alfred R. Wallace', 'Charles Darwin']

# %%
print(my_list[2:4])
# Out:
# ['World', 'Alfred R. Wallace']

# %%
my_string = "HelloWorldCharlesDarwinAlfred R. Walace"
print(my_string[0:5], my_string[5:10])
# Out:
# Hello World

# %%
print(my_string[33:39],my_string[5:10])
# Out:
# Walace World

# %%
s = "4XpQ6153pRS360bNkYfeHS12ptfhw8NVC2bP8TNIVm4R3XEEVD0eTFYRjVnDQEdtkYzGdPvlygNYQToiiWRiVTSBFwDamoniNlfJ3KbUxALb6XtuFEkSz8mOYk807ZoIm76kdiHaYUiO9Nsq8DQT8EiOmWmp6KIaRdYCQRimSC87alpinusaZH."

print(f"{s[90:95]} {s[172:179]}")
# Out:
# Damon alpinus
